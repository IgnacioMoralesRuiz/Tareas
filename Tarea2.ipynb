# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt

# %% [markdown]
# https://raw.githubusercontent.com/leoferres/gitiele356b/main/data/hdi.csv, riqueza https://raw.githubusercontent.com/leoferres/gitiele356b/main/data/pobXedadCenso.csv edad,

# %%
DFVacunas = pd.read_csv("https://raw.githubusercontent.com/MinCiencia/Datos-COVID19/master/input/Vacunacion/WORK_ARCHIVO_1.csv", ";" ,encoding='ISO-8859-1')
DFVacunas.head(10)
# Out:
#               REGION_CORTO  COD_COMUNA_FINAL FECHA_INMUNIZACION  \
# 0  Metropolitana  Santiago             13101         24/12/2020
# 1  Metropolitana  Santiago             13108         24/12/2020
# 2  Metropolitana  Santiago             13123         24/12/2020
# 3                   Bíobío              8101         25/12/2020
# 4                   Bíobío              8107         25/12/2020
# 5                   Bíobío              8110         25/12/2020
# 6                   Bíobío              8111         25/12/2020
# 7                   Bíobío              8112         25/12/2020
# 8                   Bíobío              8205         25/12/2020
# 9                   Bíobío              8301         25/12/2020
#
#    SUM_of_SUM_of_1aDOSIS  SUM_of_SUM_of_2aDOSIS  SUM_of_ÚnicaDOSIS
# 0                  280.0                    NaN                NaN
# 1                   70.0                    NaN                NaN
# ...

# %%
DFriqueza = pd.read_csv("https://raw.githubusercontent.com/leoferres/gitiele356b/main/data/hdi.csv")
DFriqueza.dropna(inplace = True)

# %%
DFedad = pd.read_csv("https://raw.githubusercontent.com/leoferres/gitiele356b/main/data/pobXedadCenso.csv")
DFedad.dropna(inplace = True)
DFedad
# Out:
#         COMUNA EDAD_0A5 EDAD_6A14 EDAD_15A64 EDAD_65YMAS
# 0         1101        0         0         15           0
# 1         1101        *         *         54          10
# 2         1101        *         0         28           *
# 3         1101        *         7         49           *
# 4         1101        *         *         26           7
# ...        ...      ...       ...        ...         ...
# 180494   15202        *         *          6           4
# 180495   15202        0         0          0           0
# 180496   15202        0         0          0           0
# 180497   15202        *         0          9           *
# 180498   15202        *         0          0           *
#
# [180499 rows x 5 columns]

# %%
DFVM = DFVacunas[DFVacunas['REGION_CORTO'] == ('Metropolitana  Santiago')]

DFVM
# Out:
#                   REGION_CORTO  COD_COMUNA_FINAL FECHA_INMUNIZACION  \
# 0      Metropolitana  Santiago             13101         24/12/2020
# 1      Metropolitana  Santiago             13108         24/12/2020
# 2      Metropolitana  Santiago             13123         24/12/2020
# 19     Metropolitana  Santiago             13101         25/12/2020
# 20     Metropolitana  Santiago             13106         25/12/2020
# ...                        ...               ...                ...
# 36991  Metropolitana  Santiago             13602         10/06/2021
# 36992  Metropolitana  Santiago             13603         10/06/2021
# 36993  Metropolitana  Santiago             13604         10/06/2021
# 36994  Metropolitana  Santiago             13604         10/06/2021
# 36995  Metropolitana  Santiago             13605         10/06/2021
#
#        SUM_of_SUM_of_1aDOSIS  SUM_of_SUM_of_2aDOSIS  SUM_of_ÚnicaDOSIS
# 0                      280.0                    NaN                NaN
# ...

# %% [markdown]
# ### En esta parte seleccioné los vacunados de la región metropolitana, y solo seleccione los datos del ultimo día suponiendo que estos serían los más actualizados

# %%
dfvm = DFVM[DFVM['FECHA_INMUNIZACION'] == ('10/06/2021')]
dfvm
# Out:
#                   REGION_CORTO  COD_COMUNA_FINAL FECHA_INMUNIZACION  \
# 36901  Metropolitana  Santiago             13101         10/06/2021
# 36902  Metropolitana  Santiago             13101         10/06/2021
# 36903  Metropolitana  Santiago             13102         10/06/2021
# 36904  Metropolitana  Santiago             13102         10/06/2021
# 36905  Metropolitana  Santiago             13103         10/06/2021
# ...                        ...               ...                ...
# 36991  Metropolitana  Santiago             13602         10/06/2021
# 36992  Metropolitana  Santiago             13603         10/06/2021
# 36993  Metropolitana  Santiago             13604         10/06/2021
# 36994  Metropolitana  Santiago             13604         10/06/2021
# 36995  Metropolitana  Santiago             13605         10/06/2021
#
#        SUM_of_SUM_of_1aDOSIS  SUM_of_SUM_of_2aDOSIS  SUM_of_ÚnicaDOSIS
# 36901                 1849.0                 2524.0                NaN
# ...

# %% [markdown]
# ### Acá seleccione del dataframe de las edades por comuna solo los datos de las comunas de la región metropolitana

# %%
dfe = DFedad.loc[DFedad['COMUNA'].isin([13101,13605])]
dfe
# Out:
#         COMUNA EDAD_0A5 EDAD_6A14 EDAD_15A64 EDAD_65YMAS
# 121508   13101       24        18        299          80
# 121509   13101        *         *        137          41
# 121510   13101       30        27        636          83
# 121511   13101       14        10        337          55
# 121512   13101        *         *        315          40
# ...        ...      ...       ...        ...         ...
# 172573   13605        0         0          *           *
# 172574   13605        *         *         10           *
# 172575   13605        *         *        187           *
# 172576   13605       20        19        164          32
# 172577   13605       12        10         69          14
#
# [1944 rows x 5 columns]

# %% [markdown]
# ### En esta parte intenté sumar las personas por edad y las agrupé en sus respectivas comunas

# %%
dfes = dfe.groupby(['COMUNA','EDAD_0A5',"EDAD_6A14","EDAD_15A64","EDAD_65YMAS"]).sum()
dfes
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
### dado mis capacidades de programación actuales no logré comprender como realizar la cor
